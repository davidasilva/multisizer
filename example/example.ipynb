# %%
import multisizer
# %matplotlib inline

# %%
exp = multisizer.coulterExperiment('data/26 Jun 2017__14-08__BaF3__t=0 drug=1e0.5__1.#m4')
exp.histogram()
multisizer.plt.xlabel('Diameter ($\mu$)');
